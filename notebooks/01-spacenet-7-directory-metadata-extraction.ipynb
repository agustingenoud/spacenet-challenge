# %% [markdown]
# # Creating and Packaging GeoDataFrame from Data

# %% [markdown]
# In the [previous notebook](https://www.kaggle.com/amerii/spacenet-7-metadata-extraction/) we dealt with the raw data labels that were in a csv format. In this notebook we are going to extract the metadata of the rest of the files in the rest of the directories. This will hopefully make our data more accessible and summarizable and make it easier to explore.
#
# Before we begin, let's begin with some note on the filenames:
#
# -     The format of a filename (as defined above for the footprint definition CSV file) is:
#    `global_monthly_<time>_mosaic_<AOI-name>_<file_type>`
#     for example:
#     `global_monthly_2018_02_mosaic_L15-0369E-1244N_1479_3214_13_UDM`
#
# - `<time>` is a timestamp in `YYYY_MM` format that represents when image collection happened.
#
# -  `<AOI-name>` is a unique identifier of a location. All AOI-names are 28 characters long.
#
# -  All ids (filenames and AOI names) are case sensitive.
#
# - `<file_type>` is either going to be a `Buildings` or `UDM` file type,
#     note that the files in the images, and images_masked directories to not have a `<file_type>`
#
# -  Image data is stored in files named `<filename>.tif` in the `images`, `images_masked` and `UDM_masks` folders. <br>
#     *Note: Not all directories have a `UDM_masks` folder*
#
# -  Vector data (Building Labels and UDM Labels) is stored in files named `<filename>.geojson` in the `labels`, `labels_match` and `labels_match_pix` directories
#
# Note: AOI stands for Area of Interest

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd 
import re
from pathlib import Path
import shapely
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from glob import glob
tqdm.pandas();

# %% [markdown]
# ## Define Directory Paths
# ### Input Directories

# %%
train_dir = Path('../data/train/')
test_dir = Path('../data/test_public/')
sample_dir = Path('../data/sample/')

# %% [markdown]
# ### Output Paths

# %%
output_path = Path.cwd().parent / 'data/'
output_csv_path = output_path/'output_csvs/'
Path(output_csv_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Extract Paths and Metadata
#
# Now that we have setup the input and output directories we can use the functions below to extract our desired metadata.
#
# The functions below will be used to extract the following metadata from a list of paths:
# * Complete Path String: <br>`../input/spacenet-7-multitemporal-urban-development/SN7_buildings_train/train/L15-0358E-1220N_1433_3310_13/images/global_monthly_2018_02_mosaic_L15-0358E-1220N_1433_3310_13.tif`
# * Mid Path String: <br>`L15-1210E-1025N_4840_4088_13/labels_match/global_monthly_2018_01_mosaic_L15-1210E-1025N_4840_4088_13_Buildings.geojson`
# * Unique File Name: `L15-0361E-1300N_1446_2989_13`
# * Directory Name: Name of the directory containing the images: `UDM_masks` `images` `images_masked` `labels `labels_match` `labels_match_pix`
# * Year: year in which the image was taken
# * Month: month in which the image was taken
# * Data Type: `Buildings` or `UDM`
# * File Extension: `.geojson` or `.tiff`
# ../input/spacenet-7-multitemporal-urban-development/SN7_buildings_train/train/L15-0361E-1300N_1c

# %%
""" def extract_metadata_from_string(string):
    # extracted groups
    # full path - image_dir_name - sub_dir_name - fname - year - month - data_type - extension
    string_mas='../'+string
    pattern = r'/(t.+|sample)/(L.+)/(\w+)/(.+_(\d+)_(\d+)_m.+_\d+_\d+_\d+)(?:_(\w+))?.(\w+)'
    filter= string_mas.find('DS_Store') 
    if filter >= 0:
        return 'DS'
    else:
        match = re.findall(pattern=pattern,string=string_mas)
        return match[0] """
    
def extract_metadata_from_string(string):
    # extracted groups
    # full path - image_dir_name - sub_dir_name - fname - year - month - data_type - extension
    pattern = r'/(t.+|sample)/(L.+)/(\w+)/(.+_(\d+)_(\d+)_m.+_\d+_\d+_\d+)(?:_(\w+))?.(\w+)'
    match = re.findall(pattern=pattern,string=string)
    return match[0]

# %%
string1 ='../data/sample/L15-0506E-1204N_2027_3374_13/UDM_masks/global_monthly_2019_11_mosaic_L15-0506E-1204N_2027_3374_13_UDM.tif'
string2 = '..data//sample/L15-0506E-1204N_2027_3374_13/images/global_monthly_2019_01_mosaic_L15-0506E-1204N_2027_3374_13.tif'
stst='../data/train/L15-0760E-0887N_3041_4643_13/labels_match_pix/global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13_Buildings.geojson'

# %%
extract_metadata_from_string(stst)
# Out:
# ('train',
#  'L15-0760E-0887N_3041_4643_13',
#  'labels_match_pix',
#  'global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13',
#  '2019',
#  '08',
#  'Buildings',
#  'geojson')

# %%
def extract_list_of_paths(directory):
    paths_list = [path for path in Path.glob(directory,pattern = '**/*.*')]
    return paths_list

# %%
""" def extract_metadata_from_list_of_paths(list_of_paths):
    d_keys = ['parent_dir','image_dir_name','sub_dir_name','fname','year','month','data_type','extension']
    d = {key:[] for key in d_keys}
    d['full_path'] = []
    for path in list_of_paths:
        print(path)
        print(str(path))
        metadata = extract_metadata_from_string(str(path))
        if metadata == 'DS':
            continue
        else:
            d['full_path'].append(path)
            
            for i,data in enumerate(metadata):
                d[d_keys[i]].append(data)
        return d """

def extract_metadata_from_list_of_paths(list_of_paths):
    d_keys = ['parent_dir','image_dir_name','sub_dir_name','fname','year','month','data_type','extension']
    d = {key:[] for key in d_keys}
    d['full_path'] = []
    for path in list_of_paths:
        metadata = extract_metadata_from_string(str(path))
        d['full_path'].append(path)
        
        for i,data in enumerate(metadata):
            d[d_keys[i]].append(data)
    return d

# %% [markdown]
# ### Extracting the Metadata
# The function below will extract a list of the paths of the files inside of the input directory

# %%
train_paths = extract_list_of_paths(directory=train_dir)
test_paths = extract_list_of_paths(directory=test_dir)
sample_paths = extract_list_of_paths(directory=sample_dir)

# %%
#extract_metadata_from_string('../train/L15-0760E-0887N_3041_4643_13/labels_match_pix/global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13_Buildings.geojson')

# %%
#extract_metadata_from_list_of_paths(train_paths[2:5])
train_paths[:2]
# Out:
# [PosixPath('../data/train/L15-0760E-0887N_3041_4643_13/labels_match_pix/global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13_Buildings.geojson'),
#  PosixPath('../data/train/L15-0760E-0887N_3041_4643_13/labels_match_pix/global_monthly_2019_02_mosaic_L15-0760E-0887N_3041_4643_13_Buildings.geojson')]

# %%
train_metadata_dict = extract_metadata_from_list_of_paths(train_paths)
test_metadata_dict = extract_metadata_from_list_of_paths(test_paths)
sample_metadata_dict = extract_metadata_from_list_of_paths(sample_paths)

# %%
#train_metadata_dict

# %%
df_train = pd.DataFrame(train_metadata_dict)
df_test = pd.DataFrame(test_metadata_dict)
df_sample = pd.DataFrame(sample_metadata_dict)

# %%
df_train
# Out:
#      parent_dir                image_dir_name      sub_dir_name  \
# 0         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 1         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 2         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 3         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 4         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# ...         ...                           ...               ...
# 8734      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8735      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8736      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8737      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8738      train  L15-1389E-1284N_5557_3054_13      labels_match
#
#                                                   fname  year month  \
# 0     global_monthly_2019_08_mosaic_L15-0760E-0887N_...  2019    08
# 1     global_monthly_2019_02_mosaic_L15-0760E-0887N_...  2019    02
# 2     global_monthly_2018_10_mosaic_L15-0760E-0887N_...  2018    10
# 3     global_monthly_2018_04_mosaic_L15-0760E-0887N_...  2018    04
# 4     global_monthly_2018_12_mosaic_L15-0760E-0887N_...  2018    12
# ...                                                 ...   ...   ...
# 8734  global_monthly_2018_08_mosaic_L15-1389E-1284N_...  2018    08
# 8735  global_monthly_2018_02_mosaic_L15-1389E-1284N_...  2018    02
# 8736  global_monthly_2019_04_mosaic_L15-1389E-1284N_...  2019    04
# 8737  global_monthly_2019_10_mosaic_L15-1389E-1284N_...  2019    10
# 8738  global_monthly_2020_01_mosaic_L15-1389E-1284N_...  2020    01
#
#       data_type extension                                          full_path
# 0     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 1     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 2     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 3     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 4     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# ...         ...       ...                                                ...
# 8734  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8735  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8736  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8737  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8738  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
#
# [8739 rows x 9 columns]

# %%
df_test
# Out:
#       parent_dir                image_dir_name   sub_dir_name  \
# 0    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 1    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 2    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 3    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 4    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# ..           ...                           ...            ...
# 461  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 462  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 463  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 464  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 465  test_public  L15-1203E-1203N_4815_3379_13  images_masked
#
#                                                  fname  year month data_type  \
# 0    global_monthly_2019_12_mosaic_L15-0391E-1219N_...  2019    12
# 1    global_monthly_2019_10_mosaic_L15-0391E-1219N_...  2019    10
# 2    global_monthly_2019_11_mosaic_L15-0391E-1219N_...  2019    11
# 3    global_monthly_2018_12_mosaic_L15-0391E-1219N_...  2018    12
# 4    global_monthly_2018_10_mosaic_L15-0391E-1219N_...  2018    10
# ..                                                 ...   ...   ...       ...
# 461  global_monthly_2017_09_mosaic_L15-1203E-1203N_...  2017    09
# 462  global_monthly_2017_08_mosaic_L15-1203E-1203N_...  2017    08
# 463  global_monthly_2018_12_mosaic_L15-1203E-1203N_...  2018    12
# 464  global_monthly_2018_10_mosaic_L15-1203E-1203N_...  2018    10
# 465  global_monthly_2018_11_mosaic_L15-1203E-1203N_...  2018    11
#
#     extension                                          full_path
# 0         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 1         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 2         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 3         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 4         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# ..        ...                                                ...
# 461       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 462       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 463       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 464       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 465       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
#
# [466 rows x 9 columns]

# %%
df_sample
# Out:
#     parent_dir                image_dir_name      sub_dir_name  \
# 0       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 1       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 2       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 3       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 4       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# ..         ...                           ...               ...
# 141     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 142     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 143     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 144     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 145     sample  L15-0506E-1204N_2027_3374_13      labels_match
#
#                                                  fname  year month  data_type  \
# 0    global_monthly_2019_09_mosaic_L15-0506E-1204N_...  2019    09  Buildings
# 1    global_monthly_2018_11_mosaic_L15-0506E-1204N_...  2018    11  Buildings
# 2    global_monthly_2018_05_mosaic_L15-0506E-1204N_...  2018    05  Buildings
# 3    global_monthly_2019_03_mosaic_L15-0506E-1204N_...  2019    03  Buildings
# 4    global_monthly_2018_07_mosaic_L15-0506E-1204N_...  2018    07  Buildings
# ..                                                 ...   ...   ...        ...
# 141  global_monthly_2018_04_mosaic_L15-0506E-1204N_...  2018    04  Buildings
# 142  global_monthly_2018_10_mosaic_L15-0506E-1204N_...  2018    10  Buildings
# 143  global_monthly_2019_02_mosaic_L15-0506E-1204N_...  2019    02  Buildings
# 144  global_monthly_2018_06_mosaic_L15-0506E-1204N_...  2018    06  Buildings
# 145  global_monthly_2018_12_mosaic_L15-0506E-1204N_...  2018    12  Buildings
#
#     extension                                          full_path
# 0     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 1     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 2     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 3     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 4     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# ..        ...                                                ...
# 141   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 142   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 143   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 144   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 145   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
#
# [146 rows x 9 columns]

# %%
df_train[df_train['data_type'] == 'Buildings']['extension'].value_counts()
# Out:
# geojson    4269
# Name: extension, dtype: int64

# %%
df_train[df_train['data_type'] == 'UDM']['extension'].value_counts()
# Out:
# geojson    1423
# tif         201
# Name: extension, dtype: int64

# %%
df_train[df_train['data_type'] == '']['extension'].value_counts()
# Out:
# tif    2846
# Name: extension, dtype: int64

# %% [markdown]
# As you may have noticed some of our data types are giving us a value of `''`. This is because as mentioned earlier the files that are actually images or `.tif` files do not have a datatype at the end.
#
# In order to remedy this problem we will simple replace the values = `''` with the value of `Images`

# %%
df_train.loc[df_train['data_type'] =='','data_type'] = 'Images'
df_test.loc[df_test['data_type'] =='','data_type'] = 'Images'
df_sample.loc[df_sample['data_type'] =='','data_type'] = 'Images'

# %%
df_train
# Out:
#      parent_dir                image_dir_name      sub_dir_name  \
# 0         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 1         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 2         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 3         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 4         train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# ...         ...                           ...               ...
# 8734      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8735      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8736      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8737      train  L15-1389E-1284N_5557_3054_13      labels_match
# 8738      train  L15-1389E-1284N_5557_3054_13      labels_match
#
#                                                   fname  year month  \
# 0     global_monthly_2019_08_mosaic_L15-0760E-0887N_...  2019    08
# 1     global_monthly_2019_02_mosaic_L15-0760E-0887N_...  2019    02
# 2     global_monthly_2018_10_mosaic_L15-0760E-0887N_...  2018    10
# 3     global_monthly_2018_04_mosaic_L15-0760E-0887N_...  2018    04
# 4     global_monthly_2018_12_mosaic_L15-0760E-0887N_...  2018    12
# ...                                                 ...   ...   ...
# 8734  global_monthly_2018_08_mosaic_L15-1389E-1284N_...  2018    08
# 8735  global_monthly_2018_02_mosaic_L15-1389E-1284N_...  2018    02
# 8736  global_monthly_2019_04_mosaic_L15-1389E-1284N_...  2019    04
# 8737  global_monthly_2019_10_mosaic_L15-1389E-1284N_...  2019    10
# 8738  global_monthly_2020_01_mosaic_L15-1389E-1284N_...  2020    01
#
#       data_type extension                                          full_path
# 0     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 1     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 2     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 3     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# 4     Buildings   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...
# ...         ...       ...                                                ...
# 8734  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8735  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8736  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8737  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
# 8738  Buildings   geojson  ../data/train/L15-1389E-1284N_5557_3054_13/lab...
#
# [8739 rows x 9 columns]

# %%
df_test
# Out:
#       parent_dir                image_dir_name   sub_dir_name  \
# 0    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 1    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 2    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 3    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# 4    test_public  L15-0391E-1219N_1567_3314_13  images_masked
# ..           ...                           ...            ...
# 461  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 462  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 463  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 464  test_public  L15-1203E-1203N_4815_3379_13  images_masked
# 465  test_public  L15-1203E-1203N_4815_3379_13  images_masked
#
#                                                  fname  year month data_type  \
# 0    global_monthly_2019_12_mosaic_L15-0391E-1219N_...  2019    12    Images
# 1    global_monthly_2019_10_mosaic_L15-0391E-1219N_...  2019    10    Images
# 2    global_monthly_2019_11_mosaic_L15-0391E-1219N_...  2019    11    Images
# 3    global_monthly_2018_12_mosaic_L15-0391E-1219N_...  2018    12    Images
# 4    global_monthly_2018_10_mosaic_L15-0391E-1219N_...  2018    10    Images
# ..                                                 ...   ...   ...       ...
# 461  global_monthly_2017_09_mosaic_L15-1203E-1203N_...  2017    09    Images
# 462  global_monthly_2017_08_mosaic_L15-1203E-1203N_...  2017    08    Images
# 463  global_monthly_2018_12_mosaic_L15-1203E-1203N_...  2018    12    Images
# 464  global_monthly_2018_10_mosaic_L15-1203E-1203N_...  2018    10    Images
# 465  global_monthly_2018_11_mosaic_L15-1203E-1203N_...  2018    11    Images
#
#     extension                                          full_path
# 0         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 1         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 2         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 3         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# 4         tif  ../data/test_public/L15-0391E-1219N_1567_3314_...
# ..        ...                                                ...
# 461       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 462       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 463       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 464       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
# 465       tif  ../data/test_public/L15-1203E-1203N_4815_3379_...
#
# [466 rows x 9 columns]

# %%
df_sample
# Out:
#     parent_dir                image_dir_name      sub_dir_name  \
# 0       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 1       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 2       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 3       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 4       sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# ..         ...                           ...               ...
# 141     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 142     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 143     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 144     sample  L15-0506E-1204N_2027_3374_13      labels_match
# 145     sample  L15-0506E-1204N_2027_3374_13      labels_match
#
#                                                  fname  year month  data_type  \
# 0    global_monthly_2019_09_mosaic_L15-0506E-1204N_...  2019    09  Buildings
# 1    global_monthly_2018_11_mosaic_L15-0506E-1204N_...  2018    11  Buildings
# 2    global_monthly_2018_05_mosaic_L15-0506E-1204N_...  2018    05  Buildings
# 3    global_monthly_2019_03_mosaic_L15-0506E-1204N_...  2019    03  Buildings
# 4    global_monthly_2018_07_mosaic_L15-0506E-1204N_...  2018    07  Buildings
# ..                                                 ...   ...   ...        ...
# 141  global_monthly_2018_04_mosaic_L15-0506E-1204N_...  2018    04  Buildings
# 142  global_monthly_2018_10_mosaic_L15-0506E-1204N_...  2018    10  Buildings
# 143  global_monthly_2019_02_mosaic_L15-0506E-1204N_...  2019    02  Buildings
# 144  global_monthly_2018_06_mosaic_L15-0506E-1204N_...  2018    06  Buildings
# 145  global_monthly_2018_12_mosaic_L15-0506E-1204N_...  2018    12  Buildings
#
#     extension                                          full_path
# 0     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 1     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 2     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 3     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 4     geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# ..        ...                                                ...
# 141   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 142   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 143   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 144   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
# 145   geojson  ../data/sample/L15-0506E-1204N_2027_3374_13/la...
#
# [146 rows x 9 columns]

# %% [markdown]
# Finally, let's create a function that automates all the steps above.

# %%
def get_metadata(input_dir):
    list_of_paths = extract_list_of_paths(input_dir)
    metadata_dict = extract_metadata_from_list_of_paths(list_of_paths)
    df = pd.DataFrame(metadata_dict)
    
    df.loc[df['data_type'] =='','data_type'] = 'Images'
    

    # Identify Images that have UDM Masks
    condition = (df['sub_dir_name'] == 'UDM_masks')
    # Get the indices of the images that have udm
    udm_indices = df.loc[condition].index
    # Get list of unique file names that have UDMs
    udm_fnames = list(df.loc[udm_indices,'fname'])
    # Get all rows that match the file names
    udm_mask = df['fname'].progress_map(lambda x: x in udm_fnames)
    # Initialize has_udm column 
    df['has_udm'] = False
    # Apply mask and update udm value
    df.loc[udm_mask,'has_udm'] = True

    return df

# %% [markdown]
# ## Saving the Outputs
# Finally we are going to save the output dataframes as csvs. We are going to have 4 csvs in total:
# * CSV for the train dataframe
# * CSV for the test dataframe
# * CSV for the sample dataframe
# * CSV for the concatenated train, test and sample dataframes

# %%
df_train = get_metadata(train_dir)
df_test = get_metadata(test_dir)
df_sample = get_metadata(sample_dir)
df_concat = pd.concat([df_train,df_test,df_sample]).reset_index()
# Out:
#   0%|          | 0/8739 [00:00<?, ?it/s]
#   0%|          | 0/466 [00:00<?, ?it/s]
#   0%|          | 0/146 [00:00<?, ?it/s]

# %%
df_train.to_csv(output_csv_path/'df_train.csv',index=False)
df_test.to_csv(output_csv_path/'df_test.csv',index=False)
df_sample.to_csv(output_csv_path/'df_sample.csv',index=False)
df_concat.to_csv(output_csv_path/'df_concat.csv',index=False)

# %%
df_train.head()
# Out:
#   parent_dir                image_dir_name      sub_dir_name  \
# 0      train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 1      train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 2      train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 3      train  L15-0760E-0887N_3041_4643_13  labels_match_pix
# 4      train  L15-0760E-0887N_3041_4643_13  labels_match_pix
#
#                                                fname  year month  data_type  \
# 0  global_monthly_2019_08_mosaic_L15-0760E-0887N_...  2019    08  Buildings
# 1  global_monthly_2019_02_mosaic_L15-0760E-0887N_...  2019    02  Buildings
# 2  global_monthly_2018_10_mosaic_L15-0760E-0887N_...  2018    10  Buildings
# 3  global_monthly_2018_04_mosaic_L15-0760E-0887N_...  2018    04  Buildings
# 4  global_monthly_2018_12_mosaic_L15-0760E-0887N_...  2018    12  Buildings
#
#   extension                                          full_path  has_udm
# 0   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...    False
# 1   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...    False
# 2   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...    False
# 3   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...    False
# 4   geojson  ../data/train/L15-0760E-0887N_3041_4643_13/lab...    False

# %% [markdown]
# Let's make sure that the output is saved

# %%
# !ls ../data/output_csvs
# Out:
# df_concat.csv            df_test.csv              global_geodataframe.gpkg
# df_sample.csv            df_train.csv             sample_geodataframe.gpkg

# %% [markdown]
# Okay so now we have saved the first version of our csv, our csv is formatted in a format known as tidy data. This format, makes it really easy to analyse our metadata. Next we are going to manipulate our dataframe so that we can make it easier to create a dataset class from it in pytorch.
#
# We are going to do this by adding a column for each of the labels paths.

# %%
def untidy_df(df):
    
    parent_dir = df['parent_dir']
    im_dir_name = df['image_dir_name']
    fname = df['fname']
    year = df['year']
    month = df['month']
    has_udm = df['has_udm']
    
    images_masked = im_dir_name + '/images_masked/' + fname + '.tif'
    
    if parent_dir == 'test_public':
            images = None
            labels_buildings = None
            labels_udm = None
            labels_match = None
            labels_match_pix = None
            udm_masks = None
    else:
        if has_udm:
            udm_masks = im_dir_name + '/UDM_masks/' + fname + '.tif'
        else:
            udm_masks = None


        images = im_dir_name + '/images/' + fname + '.tif'
        labels_buildings = im_dir_name + '/labels/' + fname + '_Buildings.geojson'
        labels_udm = im_dir_name + '/labels/' + fname + '_UDM.geojson'
        labels_match = im_dir_name + '/labels_match/' + fname + '_Buildings.geojson'
        labels_match_pix = im_dir_name + '/labels_match_pix/' + fname + '_Buildings.geojson'

    keys = ['parent_dir','image_dir_name','fname','year','month','has_udm','udm_masks','images','images_masked','labels_buildings','labels_udm','labels_match','labels_match_pix']
    values = [parent_dir,im_dir_name,fname,year,month,has_udm,udm_masks,images,images_masked,labels_buildings,labels_udm,labels_match,labels_match_pix]
    
    return {k:v for (k,v) in zip(keys,values)}

# %%
def get_untidy_frame(df):
    # apply function on input dataframe
    list_of_dicts = df.progress_apply(lambda x: untidy_df(x),axis=1)
    # drop the duplicated columns
    untidy_frame = pd.DataFrame.from_records(list_of_dicts).drop_duplicates()
    # bask in all the glory of your untidy frame ;D
    return untidy_frame

# %%
test_untidy_df = get_untidy_frame(df_test)
train_untidy_df = get_untidy_frame(df_train)
sample_untidy_df = get_untidy_frame(df_sample)
concat_untidy_df = get_untidy_frame(df_concat)
# Out:
#   0%|          | 0/466 [00:00<?, ?it/s]
#   0%|          | 0/8739 [00:00<?, ?it/s]
#   0%|          | 0/146 [00:00<?, ?it/s]
#   0%|          | 0/9351 [00:00<?, ?it/s]

# %%
concat_untidy_df
# Out:
#      parent_dir                image_dir_name  \
# 0         train  L15-0760E-0887N_3041_4643_13
# 1         train  L15-0760E-0887N_3041_4643_13
# 2         train  L15-0760E-0887N_3041_4643_13
# 3         train  L15-0760E-0887N_3041_4643_13
# 4         train  L15-0760E-0887N_3041_4643_13
# ...         ...                           ...
# 9224     sample  L15-0506E-1204N_2027_3374_13
# 9225     sample  L15-0506E-1204N_2027_3374_13
# 9226     sample  L15-0506E-1204N_2027_3374_13
# 9227     sample  L15-0506E-1204N_2027_3374_13
# 9228     sample  L15-0506E-1204N_2027_3374_13
#
#                                                   fname  year month  has_udm  \
# 0     global_monthly_2019_08_mosaic_L15-0760E-0887N_...  2019    08    False
# 1     global_monthly_2019_02_mosaic_L15-0760E-0887N_...  2019    02    False
# 2     global_monthly_2018_10_mosaic_L15-0760E-0887N_...  2018    10    False
# 3     global_monthly_2018_04_mosaic_L15-0760E-0887N_...  2018    04    False
# 4     global_monthly_2018_12_mosaic_L15-0760E-0887N_...  2018    12    False
# ...                                                 ...   ...   ...      ...
# 9224  global_monthly_2018_04_mosaic_L15-0506E-1204N_...  2018    04    False
# 9225  global_monthly_2018_10_mosaic_L15-0506E-1204N_...  2018    10    False
# 9226  global_monthly_2019_02_mosaic_L15-0506E-1204N_...  2019    02    False
# 9227  global_monthly_2018_06_mosaic_L15-0506E-1204N_...  2018    06     True
# 9228  global_monthly_2018_12_mosaic_L15-0506E-1204N_...  2018    12    False
#
#                                               udm_masks  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 9224                                               None
# 9225                                               None
# 9226                                               None
# 9227  L15-0506E-1204N_2027_3374_13/UDM_masks/global_...
# 9228                                               None
#
#                                                  images  \
# 0     L15-0760E-0887N_3041_4643_13/images/global_mon...
# 1     L15-0760E-0887N_3041_4643_13/images/global_mon...
# 2     L15-0760E-0887N_3041_4643_13/images/global_mon...
# 3     L15-0760E-0887N_3041_4643_13/images/global_mon...
# 4     L15-0760E-0887N_3041_4643_13/images/global_mon...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9225  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9226  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9227  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9228  L15-0506E-1204N_2027_3374_13/images/global_mon...
#
#                                           images_masked  \
# 0     L15-0760E-0887N_3041_4643_13/images_masked/glo...
# 1     L15-0760E-0887N_3041_4643_13/images_masked/glo...
# 2     L15-0760E-0887N_3041_4643_13/images_masked/glo...
# 3     L15-0760E-0887N_3041_4643_13/images_masked/glo...
# 4     L15-0760E-0887N_3041_4643_13/images_masked/glo...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9225  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9226  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9227  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9228  L15-0506E-1204N_2027_3374_13/images_masked/glo...
#
#                                        labels_buildings  \
# 0     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 1     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 2     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 3     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 4     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9225  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9226  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9227  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9228  L15-0506E-1204N_2027_3374_13/labels/global_mon...
#
#                                              labels_udm  \
# 0     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 1     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 2     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 3     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# 4     L15-0760E-0887N_3041_4643_13/labels/global_mon...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9225  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9226  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9227  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9228  L15-0506E-1204N_2027_3374_13/labels/global_mon...
#
#                                            labels_match  \
# 0     L15-0760E-0887N_3041_4643_13/labels_match/glob...
# 1     L15-0760E-0887N_3041_4643_13/labels_match/glob...
# 2     L15-0760E-0887N_3041_4643_13/labels_match/glob...
# 3     L15-0760E-0887N_3041_4643_13/labels_match/glob...
# 4     L15-0760E-0887N_3041_4643_13/labels_match/glob...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9225  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9226  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9227  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9228  L15-0506E-1204N_2027_3374_13/labels_match/glob...
#
#                                        labels_match_pix
# 0     L15-0760E-0887N_3041_4643_13/labels_match_pix/...
# 1     L15-0760E-0887N_3041_4643_13/labels_match_pix/...
# 2     L15-0760E-0887N_3041_4643_13/labels_match_pix/...
# 3     L15-0760E-0887N_3041_4643_13/labels_match_pix/...
# 4     L15-0760E-0887N_3041_4643_13/labels_match_pix/...
# ...                                                 ...
# 9224  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9225  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9226  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9227  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9228  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
#
# [1913 rows x 13 columns]

# %% [markdown]
# The above csv format will make it easier for us to create our custom pytorch dataset class, notice how you have access to whichever image or geojson file that you want, and how they are all grouped by the corresponding month and year.

# %% [markdown]
# # Finally we save the untidy dataframes

# %%
train_untidy_df.to_csv(output_csv_path/'df_train_untidy.csv',index=False)
test_untidy_df.to_csv(output_csv_path/'df_test_untidy.csv',index=False)
sample_untidy_df.to_csv(output_csv_path/'df_sample_untidy.csv',index=False)
concat_untidy_df.to_csv(output_csv_path/'df_concat_untidy.csv',index=False)

# %%
# !ls ../data/output_csvs
# Out:
# df_concat.csv            df_test.csv              global_geodataframe.gpkg
# df_concat_untidy.csv     df_test_untidy.csv       sample_geodataframe.gpkg
# df_sample.csv            df_train.csv
# df_sample_untidy.csv     df_train_untidy.csv

# %% [markdown]
# # What Next?
# Next we are going to create a bunch of helper functions,[in our next notebook](https://www.kaggle.com/amerii/spacenet-7-helper-functions), that will make navigating, visualizing and understanding our dataset much much easier!
