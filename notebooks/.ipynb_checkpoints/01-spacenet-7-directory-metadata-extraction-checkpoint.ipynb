# %% [markdown]
# # Creating and Packaging GeoDataFrame from Data

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd 
import re
from pathlib import Path
import shapely
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from glob import glob
tqdm.pandas();

# %% [markdown]
# ## Define Directory Paths
# ### Input Directories

# %%
train_dir = Path('/home/data/train/')
test_dir = Path('/home/data/test_public/')
sample_dir = Path('/home/data/sample/')

# %% [markdown]
# ### Output Paths

# %%
output_path = Path.cwd().parent / 'data/'
output_csv_path = output_path/'output_csvs/'
Path(output_csv_path).mkdir(parents=True, exist_ok=True)

# %%
""" def extract_metadata_from_string(string):
    # extracted groups
    # full path - image_dir_name - sub_dir_name - fname - year - month - data_type - extension
    string_mas='../'+string
    pattern = r'/(t.+|sample)/(L.+)/(\w+)/(.+_(\d+)_(\d+)_m.+_\d+_\d+_\d+)(?:_(\w+))?.(\w+)'
    filter= string_mas.find('DS_Store') 
    if filter >= 0:
        return 'DS'
    else:
        match = re.findall(pattern=pattern,string=string_mas)
        return match[0] """
    
def extract_metadata_from_string(string):
    # extracted groups
    # full path - image_dir_name - sub_dir_name - fname - year - month - data_type - extension
    pattern = r'/(t.+|sample)/(L.+)/(\w+)/(.+_(\d+)_(\d+)_m.+_\d+_\d+_\d+)(?:_(\w+))?.(\w+)'
    match = re.findall(pattern=pattern,string=string)
    return match[0]

# %%
string1 ='/home/data/sample/L15-0506E-1204N_2027_3374_13/UDM_masks/global_monthly_2019_11_mosaic_L15-0506E-1204N_2027_3374_13_UDM.tif'
string2 = '/homedata//sample/L15-0506E-1204N_2027_3374_13/images/global_monthly_2019_01_mosaic_L15-0506E-1204N_2027_3374_13.tif'
stst='/home/data/train/L15-0760E-0887N_3041_4643_13/labels_match_pix/global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13_Buildings.geojson'

# %%
extract_metadata_from_string(stst)
# Out:
# ('train',
#  'L15-0760E-0887N_3041_4643_13',
#  'labels_match_pix',
#  'global_monthly_2019_08_mosaic_L15-0760E-0887N_3041_4643_13',
#  '2019',
#  '08',
#  'Buildings',
#  'geojson')

# %%
def extract_list_of_paths(directory):
    paths_list = [path for path in Path.glob(directory,pattern = '**/*.*')]
    return paths_list

# %%
""" def extract_metadata_from_list_of_paths(list_of_paths):
    d_keys = ['parent_dir','image_dir_name','sub_dir_name','fname','year','month','data_type','extension']
    d = {key:[] for key in d_keys}
    d['full_path'] = []
    for path in list_of_paths:
        print(path)
        print(str(path))
        metadata = extract_metadata_from_string(str(path))
        if metadata == 'DS':
            continue
        else:
            d['full_path'].append(path)
            
            for i,data in enumerate(metadata):
                d[d_keys[i]].append(data)
        return d """

def extract_metadata_from_list_of_paths(list_of_paths):
    d_keys = ['parent_dir','image_dir_name','sub_dir_name','fname','year','month','data_type','extension']
    d = {key:[] for key in d_keys}
    d['full_path'] = []
    for path in list_of_paths:
        metadata = extract_metadata_from_string(str(path))
        d['full_path'].append(path)
        
        for i,data in enumerate(metadata):
            d[d_keys[i]].append(data)
    return d

# %% [markdown]
# #### Extracting the Metadata

# %%
train_paths = extract_list_of_paths(directory=train_dir)
test_paths = extract_list_of_paths(directory=test_dir)
sample_paths = extract_list_of_paths(directory=sample_dir)

# %%
train_metadata_dict = extract_metadata_from_list_of_paths(train_paths)
test_metadata_dict = extract_metadata_from_list_of_paths(test_paths)
sample_metadata_dict = extract_metadata_from_list_of_paths(sample_paths)

# %%
df_train = pd.DataFrame(train_metadata_dict)
df_test = pd.DataFrame(test_metadata_dict)
df_sample = pd.DataFrame(sample_metadata_dict)

# %%
df_train
# Out:
#      parent_dir                image_dir_name      sub_dir_name  \
# 0         train  L15-0331E-1257N_1327_3160_13            images
# 1         train  L15-0331E-1257N_1327_3160_13            images
# 2         train  L15-0331E-1257N_1327_3160_13            images
# 3         train  L15-0331E-1257N_1327_3160_13            images
# 4         train  L15-0331E-1257N_1327_3160_13            images
# ...         ...                           ...               ...
# 8734      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8735      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8736      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8737      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8738      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
#
#                                                   fname  year month  \
# 0     global_monthly_2018_01_mosaic_L15-0331E-1257N_...  2018    01
# 1     global_monthly_2018_02_mosaic_L15-0331E-1257N_...  2018    02
# 2     global_monthly_2018_03_mosaic_L15-0331E-1257N_...  2018    03
# 3     global_monthly_2018_04_mosaic_L15-0331E-1257N_...  2018    04
# 4     global_monthly_2018_05_mosaic_L15-0331E-1257N_...  2018    05
# ...                                                 ...   ...   ...
# 8734  global_monthly_2019_09_mosaic_L15-1848E-0793N_...  2019    09
# 8735  global_monthly_2019_10_mosaic_L15-1848E-0793N_...  2019    10
# 8736  global_monthly_2019_11_mosaic_L15-1848E-0793N_...  2019    11
# 8737  global_monthly_2019_12_mosaic_L15-1848E-0793N_...  2019    12
# 8738  global_monthly_2020_01_mosaic_L15-1848E-0793N_...  2020    01
#
#       data_type extension                                          full_path
# 0                     tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 1                     tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 2                     tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 3                     tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 4                     tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# ...         ...       ...                                                ...
# 8734  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8735  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8736  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8737  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8738  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
#
# [8739 rows x 9 columns]

# %%
df_test
# Out:
#       parent_dir                image_dir_name   sub_dir_name  \
# 0    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 1    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 2    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 3    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 4    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# ..           ...                           ...            ...
# 461  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 462  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 463  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 464  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 465  test_public  L15-1749E-1266N_6997_3126_13  images_masked
#
#                                                  fname  year month data_type  \
# 0    global_monthly_2018_02_mosaic_L15-0369E-1244N_...  2018    02
# 1    global_monthly_2018_03_mosaic_L15-0369E-1244N_...  2018    03
# 2    global_monthly_2018_04_mosaic_L15-0369E-1244N_...  2018    04
# 3    global_monthly_2018_05_mosaic_L15-0369E-1244N_...  2018    05
# 4    global_monthly_2018_06_mosaic_L15-0369E-1244N_...  2018    06
# ..                                                 ...   ...   ...       ...
# 461  global_monthly_2019_06_mosaic_L15-1749E-1266N_...  2019    06
# 462  global_monthly_2019_07_mosaic_L15-1749E-1266N_...  2019    07
# 463  global_monthly_2019_08_mosaic_L15-1749E-1266N_...  2019    08
# 464  global_monthly_2019_09_mosaic_L15-1749E-1266N_...  2019    09
# 465  global_monthly_2019_10_mosaic_L15-1749E-1266N_...  2019    10
#
#     extension                                          full_path
# 0         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 1         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 2         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 3         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 4         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# ..        ...                                                ...
# 461       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 462       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 463       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 464       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 465       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
#
# [466 rows x 9 columns]

# %%
df_sample
# Out:
#     parent_dir                image_dir_name      sub_dir_name  \
# 0       sample  L15-0506E-1204N_2027_3374_13         UDM_masks
# 1       sample  L15-0506E-1204N_2027_3374_13         UDM_masks
# 2       sample  L15-0506E-1204N_2027_3374_13            images
# 3       sample  L15-0506E-1204N_2027_3374_13            images
# 4       sample  L15-0506E-1204N_2027_3374_13            images
# ..         ...                           ...               ...
# 141     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 142     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 143     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 144     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 145     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
#
#                                                  fname  year month  data_type  \
# 0    global_monthly_2018_06_mosaic_L15-0506E-1204N_...  2018    06        UDM
# 1    global_monthly_2019_11_mosaic_L15-0506E-1204N_...  2019    11        UDM
# 2    global_monthly_2018_01_mosaic_L15-0506E-1204N_...  2018    01
# 3    global_monthly_2018_02_mosaic_L15-0506E-1204N_...  2018    02
# 4    global_monthly_2018_03_mosaic_L15-0506E-1204N_...  2018    03
# ..                                                 ...   ...   ...        ...
# 141  global_monthly_2019_08_mosaic_L15-0506E-1204N_...  2019    08  Buildings
# 142  global_monthly_2019_09_mosaic_L15-0506E-1204N_...  2019    09  Buildings
# 143  global_monthly_2019_10_mosaic_L15-0506E-1204N_...  2019    10  Buildings
# 144  global_monthly_2019_11_mosaic_L15-0506E-1204N_...  2019    11  Buildings
# 145  global_monthly_2019_12_mosaic_L15-0506E-1204N_...  2019    12  Buildings
#
#     extension                                          full_path
# 0         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 1         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 2         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 3         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 4         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# ..        ...                                                ...
# 141   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 142   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 143   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 144   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 145   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
#
# [146 rows x 9 columns]

# %%
df_train[df_train['data_type'] == 'Buildings']['extension'].value_counts()
# Out:
# geojson    4269
# Name: extension, dtype: int64

# %%
df_train[df_train['data_type'] == 'UDM']['extension'].value_counts()
# Out:
# geojson    1423
# tif         201
# Name: extension, dtype: int64

# %%
df_train[df_train['data_type'] == '']['extension'].value_counts()
# Out:
# tif    2846
# Name: extension, dtype: int64

# %%
df_train.loc[df_train['data_type'] =='','data_type'] = 'Images'
df_test.loc[df_test['data_type'] =='','data_type'] = 'Images'
df_sample.loc[df_sample['data_type'] =='','data_type'] = 'Images'

# %%
df_train
# Out:
#      parent_dir                image_dir_name      sub_dir_name  \
# 0         train  L15-0331E-1257N_1327_3160_13            images
# 1         train  L15-0331E-1257N_1327_3160_13            images
# 2         train  L15-0331E-1257N_1327_3160_13            images
# 3         train  L15-0331E-1257N_1327_3160_13            images
# 4         train  L15-0331E-1257N_1327_3160_13            images
# ...         ...                           ...               ...
# 8734      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8735      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8736      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8737      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
# 8738      train  L15-1848E-0793N_7394_5018_13  labels_match_pix
#
#                                                   fname  year month  \
# 0     global_monthly_2018_01_mosaic_L15-0331E-1257N_...  2018    01
# 1     global_monthly_2018_02_mosaic_L15-0331E-1257N_...  2018    02
# 2     global_monthly_2018_03_mosaic_L15-0331E-1257N_...  2018    03
# 3     global_monthly_2018_04_mosaic_L15-0331E-1257N_...  2018    04
# 4     global_monthly_2018_05_mosaic_L15-0331E-1257N_...  2018    05
# ...                                                 ...   ...   ...
# 8734  global_monthly_2019_09_mosaic_L15-1848E-0793N_...  2019    09
# 8735  global_monthly_2019_10_mosaic_L15-1848E-0793N_...  2019    10
# 8736  global_monthly_2019_11_mosaic_L15-1848E-0793N_...  2019    11
# 8737  global_monthly_2019_12_mosaic_L15-1848E-0793N_...  2019    12
# 8738  global_monthly_2020_01_mosaic_L15-1848E-0793N_...  2020    01
#
#       data_type extension                                          full_path
# 0        Images       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 1        Images       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 2        Images       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 3        Images       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# 4        Images       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...
# ...         ...       ...                                                ...
# 8734  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8735  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8736  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8737  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
# 8738  Buildings   geojson  /home/data/train/L15-1848E-0793N_7394_5018_13/...
#
# [8739 rows x 9 columns]

# %%
df_test
# Out:
#       parent_dir                image_dir_name   sub_dir_name  \
# 0    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 1    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 2    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 3    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# 4    test_public  L15-0369E-1244N_1479_3214_13  images_masked
# ..           ...                           ...            ...
# 461  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 462  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 463  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 464  test_public  L15-1749E-1266N_6997_3126_13  images_masked
# 465  test_public  L15-1749E-1266N_6997_3126_13  images_masked
#
#                                                  fname  year month data_type  \
# 0    global_monthly_2018_02_mosaic_L15-0369E-1244N_...  2018    02    Images
# 1    global_monthly_2018_03_mosaic_L15-0369E-1244N_...  2018    03    Images
# 2    global_monthly_2018_04_mosaic_L15-0369E-1244N_...  2018    04    Images
# 3    global_monthly_2018_05_mosaic_L15-0369E-1244N_...  2018    05    Images
# 4    global_monthly_2018_06_mosaic_L15-0369E-1244N_...  2018    06    Images
# ..                                                 ...   ...   ...       ...
# 461  global_monthly_2019_06_mosaic_L15-1749E-1266N_...  2019    06    Images
# 462  global_monthly_2019_07_mosaic_L15-1749E-1266N_...  2019    07    Images
# 463  global_monthly_2019_08_mosaic_L15-1749E-1266N_...  2019    08    Images
# 464  global_monthly_2019_09_mosaic_L15-1749E-1266N_...  2019    09    Images
# 465  global_monthly_2019_10_mosaic_L15-1749E-1266N_...  2019    10    Images
#
#     extension                                          full_path
# 0         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 1         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 2         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 3         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# 4         tif  /home/data/test_public/L15-0369E-1244N_1479_32...
# ..        ...                                                ...
# 461       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 462       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 463       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 464       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
# 465       tif  /home/data/test_public/L15-1749E-1266N_6997_31...
#
# [466 rows x 9 columns]

# %%
df_sample
# Out:
#     parent_dir                image_dir_name      sub_dir_name  \
# 0       sample  L15-0506E-1204N_2027_3374_13         UDM_masks
# 1       sample  L15-0506E-1204N_2027_3374_13         UDM_masks
# 2       sample  L15-0506E-1204N_2027_3374_13            images
# 3       sample  L15-0506E-1204N_2027_3374_13            images
# 4       sample  L15-0506E-1204N_2027_3374_13            images
# ..         ...                           ...               ...
# 141     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 142     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 143     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 144     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
# 145     sample  L15-0506E-1204N_2027_3374_13  labels_match_pix
#
#                                                  fname  year month  data_type  \
# 0    global_monthly_2018_06_mosaic_L15-0506E-1204N_...  2018    06        UDM
# 1    global_monthly_2019_11_mosaic_L15-0506E-1204N_...  2019    11        UDM
# 2    global_monthly_2018_01_mosaic_L15-0506E-1204N_...  2018    01     Images
# 3    global_monthly_2018_02_mosaic_L15-0506E-1204N_...  2018    02     Images
# 4    global_monthly_2018_03_mosaic_L15-0506E-1204N_...  2018    03     Images
# ..                                                 ...   ...   ...        ...
# 141  global_monthly_2019_08_mosaic_L15-0506E-1204N_...  2019    08  Buildings
# 142  global_monthly_2019_09_mosaic_L15-0506E-1204N_...  2019    09  Buildings
# 143  global_monthly_2019_10_mosaic_L15-0506E-1204N_...  2019    10  Buildings
# 144  global_monthly_2019_11_mosaic_L15-0506E-1204N_...  2019    11  Buildings
# 145  global_monthly_2019_12_mosaic_L15-0506E-1204N_...  2019    12  Buildings
#
#     extension                                          full_path
# 0         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 1         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 2         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 3         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 4         tif  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# ..        ...                                                ...
# 141   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 142   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 143   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 144   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
# 145   geojson  /home/data/sample/L15-0506E-1204N_2027_3374_13...
#
# [146 rows x 9 columns]

# %%
def get_metadata(input_dir):
    list_of_paths = extract_list_of_paths(input_dir)
    metadata_dict = extract_metadata_from_list_of_paths(list_of_paths)
    df = pd.DataFrame(metadata_dict)
    
    df.loc[df['data_type'] =='','data_type'] = 'Images'
    

    # Identify Images that have UDM Masks
    condition = (df['sub_dir_name'] == 'UDM_masks')
    # Get the indices of the images that have udm
    udm_indices = df.loc[condition].index
    # Get list of unique file names that have UDMs
    udm_fnames = list(df.loc[udm_indices,'fname'])
    # Get all rows that match the file names
    udm_mask = df['fname'].progress_map(lambda x: x in udm_fnames)
    # Initialize has_udm column 
    df['has_udm'] = False
    # Apply mask and update udm value
    df.loc[udm_mask,'has_udm'] = True

    return df

# %% [markdown]
# #### Saving the Outputs

# %%
df_train = get_metadata(train_dir)
df_test = get_metadata(test_dir)
df_sample = get_metadata(sample_dir)
df_concat = pd.concat([df_train,df_test,df_sample]).reset_index()
# Out:
#   0%|          | 0/8739 [00:00<?, ?it/s]
#   0%|          | 0/466 [00:00<?, ?it/s]
#   0%|          | 0/146 [00:00<?, ?it/s]

# %%
df_train.to_csv(output_csv_path/'df_train.csv',index=False)
df_test.to_csv(output_csv_path/'df_test.csv',index=False)
df_sample.to_csv(output_csv_path/'df_sample.csv',index=False)
df_concat.to_csv(output_csv_path/'df_concat.csv',index=False)

# %%
df_train.head()
# Out:
#   parent_dir                image_dir_name sub_dir_name  \
# 0      train  L15-0331E-1257N_1327_3160_13       images
# 1      train  L15-0331E-1257N_1327_3160_13       images
# 2      train  L15-0331E-1257N_1327_3160_13       images
# 3      train  L15-0331E-1257N_1327_3160_13       images
# 4      train  L15-0331E-1257N_1327_3160_13       images
#
#                                                fname  year month data_type  \
# 0  global_monthly_2018_01_mosaic_L15-0331E-1257N_...  2018    01    Images
# 1  global_monthly_2018_02_mosaic_L15-0331E-1257N_...  2018    02    Images
# 2  global_monthly_2018_03_mosaic_L15-0331E-1257N_...  2018    03    Images
# 3  global_monthly_2018_04_mosaic_L15-0331E-1257N_...  2018    04    Images
# 4  global_monthly_2018_05_mosaic_L15-0331E-1257N_...  2018    05    Images
#
#   extension                                          full_path  has_udm
# 0       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...    False
# 1       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...    False
# 2       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...    False
# 3       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...    False
# 4       tif  /home/data/train/L15-0331E-1257N_1327_3160_13/...    False

# %%
# !ls ../data/output_csvs
# Out:
# df_concat.csv  df_test.csv   global_geodataframe.gpkg
# df_sample.csv  df_train.csv  sample_geodataframe.gpkg

# %%
def untidy_df(df):
    
    parent_dir = df['parent_dir']
    im_dir_name = df['image_dir_name']
    fname = df['fname']
    year = df['year']
    month = df['month']
    has_udm = df['has_udm']
    
    images_masked = im_dir_name + '/images_masked/' + fname + '.tif'
    
    if parent_dir == 'test_public':
            images = None
            labels_buildings = None
            labels_udm = None
            labels_match = None
            labels_match_pix = None
            udm_masks = None
    else:
        if has_udm:
            udm_masks = im_dir_name + '/UDM_masks/' + fname + '.tif'
        else:
            udm_masks = None


        images = im_dir_name + '/images/' + fname + '.tif'
        labels_buildings = im_dir_name + '/labels/' + fname + '_Buildings.geojson'
        labels_udm = im_dir_name + '/labels/' + fname + '_UDM.geojson'
        labels_match = im_dir_name + '/labels_match/' + fname + '_Buildings.geojson'
        labels_match_pix = im_dir_name + '/labels_match_pix/' + fname + '_Buildings.geojson'

    keys = ['parent_dir','image_dir_name','fname','year','month','has_udm','udm_masks','images','images_masked','labels_buildings','labels_udm','labels_match','labels_match_pix']
    values = [parent_dir,im_dir_name,fname,year,month,has_udm,udm_masks,images,images_masked,labels_buildings,labels_udm,labels_match,labels_match_pix]
    
    return {k:v for (k,v) in zip(keys,values)}

# %%
def get_untidy_frame(df):
    # apply function on input dataframe
    list_of_dicts = df.progress_apply(lambda x: untidy_df(x),axis=1)
    # drop the duplicated columns
    untidy_frame = pd.DataFrame.from_records(list_of_dicts).drop_duplicates()
    # bask in all the glory of your untidy frame ;D
    return untidy_frame

# %%
test_untidy_df = get_untidy_frame(df_test)
train_untidy_df = get_untidy_frame(df_train)
sample_untidy_df = get_untidy_frame(df_sample)
concat_untidy_df = get_untidy_frame(df_concat)
# Out:
#   0%|          | 0/466 [00:00<?, ?it/s]
#   0%|          | 0/8739 [00:00<?, ?it/s]
#   0%|          | 0/146 [00:00<?, ?it/s]
#   0%|          | 0/9351 [00:00<?, ?it/s]

# %%
concat_untidy_df
# Out:
#      parent_dir                image_dir_name  \
# 0         train  L15-0331E-1257N_1327_3160_13
# 1         train  L15-0331E-1257N_1327_3160_13
# 2         train  L15-0331E-1257N_1327_3160_13
# 3         train  L15-0331E-1257N_1327_3160_13
# 4         train  L15-0331E-1257N_1327_3160_13
# ...         ...                           ...
# 9225     sample  L15-0506E-1204N_2027_3374_13
# 9226     sample  L15-0506E-1204N_2027_3374_13
# 9227     sample  L15-0506E-1204N_2027_3374_13
# 9228     sample  L15-0506E-1204N_2027_3374_13
# 9230     sample  L15-0506E-1204N_2027_3374_13
#
#                                                   fname  year month  has_udm  \
# 0     global_monthly_2018_01_mosaic_L15-0331E-1257N_...  2018    01    False
# 1     global_monthly_2018_02_mosaic_L15-0331E-1257N_...  2018    02    False
# 2     global_monthly_2018_03_mosaic_L15-0331E-1257N_...  2018    03    False
# 3     global_monthly_2018_04_mosaic_L15-0331E-1257N_...  2018    04    False
# 4     global_monthly_2018_05_mosaic_L15-0331E-1257N_...  2018    05    False
# ...                                                 ...   ...   ...      ...
# 9225  global_monthly_2019_07_mosaic_L15-0506E-1204N_...  2019    07    False
# 9226  global_monthly_2019_08_mosaic_L15-0506E-1204N_...  2019    08    False
# 9227  global_monthly_2019_09_mosaic_L15-0506E-1204N_...  2019    09    False
# 9228  global_monthly_2019_10_mosaic_L15-0506E-1204N_...  2019    10    False
# 9230  global_monthly_2019_12_mosaic_L15-0506E-1204N_...  2019    12    False
#
#      udm_masks                                             images  \
# 0         None  L15-0331E-1257N_1327_3160_13/images/global_mon...
# 1         None  L15-0331E-1257N_1327_3160_13/images/global_mon...
# 2         None  L15-0331E-1257N_1327_3160_13/images/global_mon...
# 3         None  L15-0331E-1257N_1327_3160_13/images/global_mon...
# 4         None  L15-0331E-1257N_1327_3160_13/images/global_mon...
# ...        ...                                                ...
# 9225      None  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9226      None  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9227      None  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9228      None  L15-0506E-1204N_2027_3374_13/images/global_mon...
# 9230      None  L15-0506E-1204N_2027_3374_13/images/global_mon...
#
#                                           images_masked  \
# 0     L15-0331E-1257N_1327_3160_13/images_masked/glo...
# 1     L15-0331E-1257N_1327_3160_13/images_masked/glo...
# 2     L15-0331E-1257N_1327_3160_13/images_masked/glo...
# 3     L15-0331E-1257N_1327_3160_13/images_masked/glo...
# 4     L15-0331E-1257N_1327_3160_13/images_masked/glo...
# ...                                                 ...
# 9225  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9226  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9227  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9228  L15-0506E-1204N_2027_3374_13/images_masked/glo...
# 9230  L15-0506E-1204N_2027_3374_13/images_masked/glo...
#
#                                        labels_buildings  \
# 0     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 1     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 2     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 3     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 4     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# ...                                                 ...
# 9225  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9226  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9227  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9228  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9230  L15-0506E-1204N_2027_3374_13/labels/global_mon...
#
#                                              labels_udm  \
# 0     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 1     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 2     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 3     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# 4     L15-0331E-1257N_1327_3160_13/labels/global_mon...
# ...                                                 ...
# 9225  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9226  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9227  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9228  L15-0506E-1204N_2027_3374_13/labels/global_mon...
# 9230  L15-0506E-1204N_2027_3374_13/labels/global_mon...
#
#                                            labels_match  \
# 0     L15-0331E-1257N_1327_3160_13/labels_match/glob...
# 1     L15-0331E-1257N_1327_3160_13/labels_match/glob...
# 2     L15-0331E-1257N_1327_3160_13/labels_match/glob...
# 3     L15-0331E-1257N_1327_3160_13/labels_match/glob...
# 4     L15-0331E-1257N_1327_3160_13/labels_match/glob...
# ...                                                 ...
# 9225  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9226  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9227  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9228  L15-0506E-1204N_2027_3374_13/labels_match/glob...
# 9230  L15-0506E-1204N_2027_3374_13/labels_match/glob...
#
#                                        labels_match_pix
# 0     L15-0331E-1257N_1327_3160_13/labels_match_pix/...
# 1     L15-0331E-1257N_1327_3160_13/labels_match_pix/...
# 2     L15-0331E-1257N_1327_3160_13/labels_match_pix/...
# 3     L15-0331E-1257N_1327_3160_13/labels_match_pix/...
# 4     L15-0331E-1257N_1327_3160_13/labels_match_pix/...
# ...                                                 ...
# 9225  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9226  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9227  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9228  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
# 9230  L15-0506E-1204N_2027_3374_13/labels_match_pix/...
#
# [1913 rows x 13 columns]

# %% [markdown]
# The above csv format will make it easier for us to create our custom pytorch dataset class, notice how you have access to whichever image or geojson file that you want, and how they are all grouped by the corresponding month and year.

# %% [markdown]
# ### Finally we save the untidy dataframes

# %%
train_untidy_df.to_csv(output_csv_path/'df_train_untidy.csv',index=False)
test_untidy_df.to_csv(output_csv_path/'df_test_untidy.csv',index=False)
sample_untidy_df.to_csv(output_csv_path/'df_sample_untidy.csv',index=False)
concat_untidy_df.to_csv(output_csv_path/'df_concat_untidy.csv',index=False)

# %%
# !ls ../data/output_csvs
# Out:
# df_concat.csv	      df_test.csv	   global_geodataframe.gpkg
# df_concat_untidy.csv  df_test_untidy.csv   sample_geodataframe.gpkg
# df_sample.csv	      df_train.csv
# df_sample_untidy.csv  df_train_untidy.csv
